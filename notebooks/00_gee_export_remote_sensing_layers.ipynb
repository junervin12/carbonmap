# %% [markdown]
# # 00 — Google Earth Engine Export of Remote Sensing Layers
#
# This notebook is part of the reproducible workflow for the multi-source geospatial AI framework.

# %% [markdown]
# This notebook documents the Google Earth Engine exports required by the downstream Python workflow. The JavaScript version is provided in `scripts/gee_export_remote_sensing_layers.js`. Run the script in the Google Earth Engine Code Editor and export the GeoTIFF files to Google Drive.

# %%
# This cell is informational. Use the JavaScript code in scripts/gee_export_remote_sensing_layers.js in the GEE Code Editor.
expected_outputs = [
    'sentinel2_indices_jawa_barat_2024_scale50.tif',
    'viirs_nighttime_lights_jawa_barat_2024.tif',
    'esa_worldcover_jawa_barat.tif',
    'cropland_mask_jawa_barat.tif',
]
for item in expected_outputs:
    print(item)

# %% [markdown]
# Recommended exports use the West Java boundary, annual or dry-season cloud-masked Sentinel-2 composite, VIIRS annual nighttime lights, ESA WorldCover, and a binary cropland mask.
